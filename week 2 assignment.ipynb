# %% [markdown]
# Q1. How do you comment code in Python? What are the different types of comments?

# %%
# for single line comment we use hash before the comment like I used.

# %%
# there is multiline comment also , which is 
print("life is so beautiful")
# Out:
# life is so beautiful

# %% [markdown]
# Q2. What are variables in Python? How do you declare and assign values to variables?

# %%
# here a,b,c,d are Variables,for example
# Python 3 code to demonstrate variable assignment
# Assign variable directly
a = 5
b = 3

# %%
a,b
# Out:
# (5, 3)

# %% [markdown]
# Q3. How do you convert one data type to another in Python?

# %%
# now to convert one data type to another in Python we will write it as

a = 10
print(type(a))
 
b = 10.0
print(type(b))
 
c = a//b
print(c)
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# 1.0
# <class 'float'>

# %% [markdown]
# Q4. How do you write and execute a Python script from the command line?

# %% [markdown]
# step 1 - Go to the extension section or press ‘Ctrl+Shift+X’ on Windows, then search and install the extension named ‘Python’ and ‘Code Runner’. Restart your vs code after that.
# step 2 -create a new file with the name ‘hello.py’ and write the below code in it:
# print('Hello World!')

# %% [markdown]
# ![coco.png](attachment:coco.png)

# %% [markdown]
# Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].

# %%
# Initialize list
Lst = [1,2,3,4,5]
 
# Display list
print(Lst[1:3:1])
# Out:
# [2, 3]

# %% [markdown]
# Q6. What is a complex number in mathematics, and how is it represented in Python?

# %%
# Initializing complex number
z = 8+4j
# Print the parts of Complex No.
print("The real part of complex number is : ", end="")
print(z.real)
 
print("The imaginary part of complex number is : ", end="")
print(z.imag)
# Out:
# The real part of complex number is : 8.0
# The imaginary part of complex number is : 4.0

# %% [markdown]
# Q7. What is the correct way to declare a variable named age and assign the value 25 to it?

# %%
# the correct way to declare a variable named ageand assign the value 25 
age = 25

# %%
age
# Out:
# 25

# %% [markdown]
# Q8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable
# belong to?

# %%
price = 9.99
print("Data type is belong to",type(price))
# Out:
# Data type is belong to <class 'float'>

# %% [markdown]
# Q9. Create a variable named name and assign your full name to it as a string. How would you print the
# value of this variable?

# %%
a = "my name is Shrinkhala Jaiswal."
print(a)
# Out:
# my name is Shrinkhala Jaiswal.

# %% [markdown]
# Q10. Given the string "Hello, World!", extract the substring "World".

# %%
name="Hello, World!"
print("",name[7:12])
# Out:
#  World

# %% [markdown]
# Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are
# currently a student or not.

# %%
is_student=True
print(is_student)
# Out:
# True
